# %% [markdown]
# ## 데이터 통합 및 변형 연습문제
#
# - 데이터 통합, 멀티인덱스 기능 활용

# %% [markdown]
# #### 필요한 모듈 임포트

# %% [markdown]
# ### 1. 데이터 준비
# house 폴더에 저장되어 있는 데이터 파일들을 사용하여 주어진 문제를 해결하세요.
# - 제공데이터 출처 : 공공데이터 포털(https://www.data.go.kr/)
# - 제공데이터 : 나주시, 서산시, 충주시의 최근에 등록된 주택보급률 데이터(csv파일)
#     - 2010년~2024년12월
#     - 지역마다 업로드 일자가 다름
# - 데이터는 data폴더 아래 house폴더에 저장하여 사용

# %%
# 데이터 폴더에 있는 파일목록 확인
from glob import glob

glob('data/house/*.csv')
# Out:
# ['data/house\\나주시_주택현황 및 보급률(2004~2020).csv',
#  'data/house\\나주시_주택현황 및 보급률_2021년.csv',
#  'data/house\\서산시_주택현황 및 보급률(2002~2007).csv',
#  'data/house\\서산시_주택현황 및 보급률(2008~2012).csv',
#  'data/house\\서산시_주택현황 및 보급률(2013~2022).csv',
#  'data/house\\충주시_주택현황 및 보급률(2003~2020).csv',
#  'data/house\\충주시_주택현황 및 보급률(2019~2021).csv']

# %% [markdown]
# #### 2. 데이터 파일(csv)을 읽어 데이터프레임으로 저장하기
# : 데이터파일(csv)을 엑셀로 열어 구조를 확인하고, pandas 데이터프레임으로 저장

# %% [markdown]
# - 나주시 주택보급률

# %% [markdown]
# - 서산시 주택보급률

# %% [markdown]
# - 충추시 주택보급률

# %% [markdown]
# #### 3. 생성한 데이터프레임을 하나의 데이터 프레임으로 통합하기 위해 공통된 형식으로 변형하기

# %% [markdown]
# #### 4. 세 지역의 주택보급률을 하나의 데이터프레임으로 통합하기

# %% [markdown]
# #### 5. 지역별 데이터프레임과 통합한 데이터프레임을 각각 csv 파일로 저장하기

# %% [markdown]
# ---

# %% [markdown]
# ----
