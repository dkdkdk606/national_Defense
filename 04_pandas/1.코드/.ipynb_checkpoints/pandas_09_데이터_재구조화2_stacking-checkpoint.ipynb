# %%
import numpy as np
import pandas as pd
import seaborn as sns

print(f'numpy : {np.__version__}, pandas : {pd.__version__}, seaborn : {sns.__version__}')
# Out:
# numpy : 2.5.2, pandas : 3.0.5, seaborn : 0.13.2

# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = 'all'

# %% [markdown]
# # pandas 데이터 재구조화(reshaping)

# %% [markdown]
# - 피벗팅(pivoting)
# - 스태킹(stacking)과 언스태킹(unstacking)
# - 멜팅(melting)과 와이드투롱(wide_to_long)
# - 교차표(crosstab)
# - explode

# %% [markdown]
# ## 2. 스태킹(stacking)과 언스태깅(unstacking)

# %% [markdown]
# : 피벗팅과 유사하지만 계층형 인덱스의 특정 수준도 회전이 가능함
#
# - 스태킹(stacking) : column labels과 그 값을 row index와 값으로 회전시킴
# - 언스태킹(unstacking) : row index와 그 값이 column labels과 값으로 회전시킴

# %% [markdown]
# ![image.png](https://img1.daumcdn.net/thumb/R1280x0/?scode=mtistory2&fname=https%3A%2F%2Ft1.daumcdn.net%2Fcfile%2Ftistory%2F99BBDC48601405E621)
#
# - 출처 : https://rfriend.tistory.com/276

# %% [markdown]
# ### **1. 스태킹(stacking)**

# %% [markdown]
# ![image.png](https://pandas.pydata.org/docs/_images/reshaping_stack.png)

# %% [markdown]
# - **DataFrame.stack(level=- 1, dropna=True)**
#     - level : int, str, list, default=-1
#         - 언스태킹을 적용하는 레벨
#         - 기본값은 마지막 레벨 : 언스태킹 결과 항상 마지막 레벨로 이동
#     - dropna : bool, default True
#         - 스태킹 결과 결측치 처리 여부, 기본값은 True로 결측치 제외

# %% [markdown]
# - https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.stack.html

# %% [markdown]
# #### 예제1. single level columns를 갖는 데이터

# %%
df = pd.DataFrame([[10,11],[12,13]],
                  index=['cat','dog'],
                  columns=['weight','height'])
df
# Out:
#      weight  height
# cat      10      11
# dog      12      13

# %% [markdown]
# - stack() : 컬럼이 인덱스 마지막 레벨로 변경 -> 시리즈 데이터로 변환

# %%
df.stack()
# Out:
# cat  weight    10
#      height    11
# dog  weight    12
#      height    13
# dtype: int64

# %% [markdown]
# #### 예제2. multi-level columns을 갖는 데이터1

# %%
muticol = pd.MultiIndex.from_tuples([('weight','kg'),
                                     ('weight','pounds')])
df2 = pd.DataFrame([[10,11],[12,13]],
                  index=['cat','dog'],
                  columns=muticol)
df2
# Out:
#     weight
#         kg pounds
# cat     10     11
# dog     12     13

# %% [markdown]
# - stack() : 컬럼의 마지막 레벨이 인덱스의 마지막 레벨로 이동

# %%
df2.stack()
# Out:
#             weight
# cat kg          10
#     pounds      11
# dog kg          12
#     pounds      13

# %%
df2.stack(0)
# Out:
#             kg  pounds
# cat weight  10      11
# dog weight  12      13

# %% [markdown]
# #### 예제3. multi-level columns을 갖는 데이터2

# %%
muticol2 = pd.MultiIndex.from_tuples([('weight','kg'),
                                     ('height','m')])
df3 = pd.DataFrame([[10,1.1],[12,1.3]],
                  index=['cat','dog'],
                  columns=muticol2)
df3
# Out:
#     weight height
#         kg      m
# cat     10    1.1
# dog     12    1.3

# %% [markdown]
# - stack(level=-1)

# %% [markdown]
# - stack(0) : 컬럼의 첫번째 레벨이 인덱스의 마지막 레벨로 이동

# %%
df3
df3.stack()
df3.stack(0)
# Out:
#     weight height
#         kg      m
# cat     10    1.1
# dog     12    1.3
#         weight  height
# cat kg    10.0     NaN
#     m      NaN     1.1
# dog kg    12.0     NaN
#     m      NaN     1.3
#               kg    m
# cat weight  10.0  NaN
#     height   NaN  1.1
# dog weight  12.0  NaN
#     height   NaN  1.3

# %% [markdown]
# - stack([0,1]) : 컬럼의 두 레벨이 인덱스의 마지막 두 레벨로 이동

# %%
df3.stack([0,1])
# Out:
# cat  weight  kg    10.0
#      height  m      1.1
# dog  weight  kg    12.0
#      height  m      1.3
# dtype: float64

# %% [markdown]
# #### 예제4. multi-level columns을 갖는 데이터3 : 결측치를 포함하는 경우

# %%
muticol2 = pd.MultiIndex.from_tuples([('weight','kg'),
                                     ('height','m')])
df4 = pd.DataFrame([[None,1.1],[12,1.3]],
                  index=['cat','dog'],
                  columns=muticol2)
df4
# Out:
#     weight height
#         kg      m
# cat    NaN    1.1
# dog   12.0    1.3

# %% [markdown]
# - stack()

# %%
df4.stack()
# Out:
#         weight  height
# cat kg     NaN     NaN
#     m      NaN     1.1
# dog kg    12.0     NaN
#     m      NaN     1.3

# %% [markdown]
# - stack(, dropna=True|False)

# %%
# df4.stack(dropna = False)
# -> 에러
# 그 행의 모든 데이터가 nan인 경우 행 삭제 : future_satck=False인 경우 적용하나 사용하지 말것을 권장: 
# 판다스 최신 버전의 새로운 리셰이핑 엔진(stack_v3)은 애초에 의미 없는 NaN 행을 만들지 않도록 설계되었어.
# 판다스 개발팀은 향후 버전에서 dropna 아예 인자를 완전히 제거할 계획
df4.stack(future_stack=False, dropna=True)
# -> 경고 : 강제로 이전버젼으로 실행해서 실행이 되긴
# Out:
# C:\Users\acorn2\AppData\Local\Temp\ipykernel_21740\2603669055.py:6: Pandas4Warning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Do not specify the future_stack argument to adopt the new implementation and silence this warning.
#   df4.stack(future_stack=False, dropna=True)
#         weight  height
# cat m      NaN     1.1
# dog kg    12.0     NaN
#     m      NaN     1.3

# %% [markdown]
# ### **2. 언스태킹(unstacking)**

# %% [markdown]
# ![image.png](https://pandas.pydata.org/docs/_images/reshaping_unstack.png)

# %% [markdown]
# - **DataFrame.unstack(level=- 1, fill_value=None, sort=True)**
#     - level : int, str, list, default=-1
#         - 언스태킹을 적용하는 레벨
#         - 기본값은 마지막 레벨 : 언스태킹 결과 항상 마지막 레벨로 이동
#     - fill_value : int, str or dict
#         - 언스태킹 결과 결측치는 NaN으로 대체
#     - sort : bool, default True
#         - 멀티인덱스 컬럼의 레벨

# %% [markdown]
# - https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.unstack.html

# %% [markdown]
# - 예제5. 시리즈 데이터

# %%
idx = pd.MultiIndex.from_tuples([('one','a'),('one','b'),('two','a'),('two','b')])
s = pd.Series(np.arange(1.0,5.0), index=idx)
s
# Out:
# one  a    1.0
#      b    2.0
# two  a    3.0
#      b    4.0
# dtype: float64

# %% [markdown]
# - unstack() : 마지막레벨로 unstacking

# %%
s.unstack()
s.unstack(-1)
s.unstack(level=-1)
# 3개 다 완전 동일
# Out:
#        a    b
# one  1.0  2.0
# two  3.0  4.0
#        a    b
# one  1.0  2.0
# two  3.0  4.0
#        a    b
# one  1.0  2.0
# two  3.0  4.0

# %% [markdown]
# - unstack(level=0)

# %%
s.unstack(0)
# Out:
#    one  two
# a  1.0  3.0
# b  2.0  4.0

# %% [markdown]
# #### 예제6. 행이 MultiIndex를 갖는 데이터

# %%
lists = ['bar bar baz baz foo foo qux qux'.split(),
         'one two'.split()*4]
lists
idx = pd.MultiIndex.from_arrays(lists, names=['first','second'])
df = pd.DataFrame(np.round(np.random.randn(8,2), 2),
                  index=idx, columns=['A','B'])
df
# Out:
# [['bar', 'bar', 'baz', 'baz', 'foo', 'foo', 'qux', 'qux'],
#  ['one', 'two', 'one', 'two', 'one', 'two', 'one', 'two']]
#                  A     B
# first second
# bar   one    -2.64  0.11
#       two    -0.11  1.84
# baz   one    -0.11  1.07
#       two    -0.33 -0.21
# foo   one    -1.07  1.06
#       two    -3.02 -0.28
# qux   one    -0.74 -1.15
#       two    -0.47  0.51

# %% [markdown]
# - unstack() : index의 마지막레벨이 컬럼의 마지막 레벨로 이동

# %%
df.unstack()
# Out:
#            A           B
# second   one   two   one   two
# first
# bar    -2.64 -0.11  0.11  1.84
# baz    -0.11 -0.33  1.07 -0.21
# foo    -1.07 -3.02  1.06 -0.28
# qux    -0.74 -0.47 -1.15  0.51

# %% [markdown]
# - unstack(0) : index의 첫번째 레벨이 컬럼의 마지막 레벨로 이동

# %% [markdown]
# ![image.png](https://pandas.pydata.org/docs/_images/reshaping_unstack_0.png)

# %%
df.unstack(0)
# Out:
#            A                       B
# first    bar   baz   foo   qux   bar   baz   foo   qux
# second
# one    -2.64 -0.11 -1.07 -0.74  0.11  1.07  1.06 -1.15
# two    -0.11 -0.33 -3.02 -0.47  1.84 -0.21 -0.28  0.51

# %% [markdown]
# - unstack(1) : index의 두첫번째 레벨이 컬럼의 마지막 레벨로 이동

# %% [markdown]
# ![image.png](https://pandas.pydata.org/docs/_images/reshaping_unstack_1.png)

# %%
df.unstack(1)
# Out:
#            A           B
# second   one   two   one   two
# first
# bar    -2.64 -0.11  0.11  1.84
# baz    -0.11 -0.33  1.07 -0.21
# foo    -1.07 -3.02  1.06 -0.28
# qux    -0.74 -0.47 -1.15  0.51

# %%
df
df.unstack('first')
df.unstack('second')
# Out:
#                  A     B
# first second
# bar   one    -2.64  0.11
#       two    -0.11  1.84
# baz   one    -0.11  1.07
#       two    -0.33 -0.21
# foo   one    -1.07  1.06
#       two    -3.02 -0.28
# qux   one    -0.74 -1.15
#       two    -0.47  0.51
#            A                       B
# first    bar   baz   foo   qux   bar   baz   foo   qux
# second
# one    -2.64 -0.11 -1.07 -0.74  0.11  1.07  1.06 -1.15
# two    -0.11 -0.33 -3.02 -0.47  1.84 -0.21 -0.28  0.51
#            A           B
# second   one   two   one   two
# first
# bar    -2.64 -0.11  0.11  1.84
# baz    -0.11 -0.33  1.07 -0.21
# foo    -1.07 -3.02  1.06 -0.28
# qux    -0.74 -0.47 -1.15  0.51

# %% [markdown]
# #### 예제7. 행과 열이 모두 MultiIndex를 갖는 데이터

# %%
idx = pd.MultiIndex.from_product(['bar baz foo qux'.split(), ('one','two')],
                                 names=['first','second'])
cols = pd.MultiIndex.from_tuples([('A','cat'),('B','dog'),('B','cat'),('A','dog')],
                                 names=['category','animal'])
df = pd.DataFrame(np.round(np.random.randn(8,4), 2),
                  index=idx, columns=cols)
df
# Out:
# category         A     B           A
# animal         cat   dog   cat   dog
# first second
# bar   one    -1.71  0.07 -1.43 -0.38
#       two     0.18 -0.89  1.21 -0.02
# baz   one     0.45  0.57 -0.42 -1.08
#       two     1.13  0.65 -0.39  0.28
# foo   one    -1.45  0.33  0.95  0.59
#       two     0.63 -1.24 -0.14 -0.13
# qux   one    -0.63 -0.14  0.00 -0.78
#       two    -0.11 -0.24 -2.31  0.76

# %%
df.loc[('bar','one'),('A','cat')]
# Out:
# np.float64(-1.71)

# %%
df.unstack()
# Out:
# category     A           B                       A
# animal     cat         dog         cat         dog
# second     one   two   one   two   one   two   one   two
# first
# bar      -1.71  0.18  0.07 -0.89 -1.43  1.21 -0.38 -0.02
# baz       0.45  1.13  0.57  0.65 -0.42 -0.39 -1.08  0.28
# foo      -1.45  0.63  0.33 -1.24  0.95 -0.14  0.59 -0.13
# qux      -0.63 -0.11 -0.14 -0.24  0.00 -2.31 -0.78  0.76

# %%
df.iloc[[0,1,4,7],[1,2]]
# Out:
# category         B
# animal         dog   cat
# first second
# bar   one     0.07 -1.43
#       two    -0.89  1.21
# foo   one     0.33  0.95
# qux   two    -0.24 -2.31

# %%
df.iloc[[0,1,4,7],[1,2]].unstack()
# Out:
# category     B
# animal     dog         cat
# second     one   two   one   two
# first
# bar       0.07 -0.89 -1.43  1.21
# foo       0.33   NaN  0.95   NaN
# qux        NaN -0.24   NaN -2.31

# %% [markdown]
# ### 예제8. 결측치가 있는 데이터프레임

# %% [markdown]
# - unstack( , **fill_value=**)

# %%
df.iloc[[0,1,4,7],[1,2]].unstack(fill_value=0)
# Out:
# category     B
# animal     dog         cat
# second     one   two   one   two
# first
# bar       0.07 -0.89 -1.43  1.21
# foo       0.33  0.00  0.95  0.00
# qux       0.00 -0.24  0.00 -2.31

# %% [markdown]
# ----
