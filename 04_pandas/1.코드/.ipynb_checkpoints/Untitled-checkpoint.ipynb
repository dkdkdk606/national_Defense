# %%
Chapter 02 데이터 분석과 판다스
[01] 다음 중 파이썬, 넘파이, 판다스의 자료구조 중 2차원 데이터를 위한 것이 아닌 것을 고르시오.
01 list
02 ndarray
03 Series
04 DataFrame
->1

# %%
[02] 다음 데이터는 연속형인지 범주형인지 쓰시오.
(1) 지지 정당(A, B, C)        범주
(2) 몸무게(61, 65, 54, 70)    연속
(3) 시력(0.8, 0.7, 1.2, 1.5)  연속
(4) 혈액형(A, B, O, AB)       범주

# %%
[03] 다음은 데이터 분석 절차 중 이 단계에 대한 설명인지 보기에 고르시오.
(1) 설문조사 결과에서 결측값을 찾아 제거하였다.
(2) 주어진 데이터에 대해 군집 분석과 분류 분석을 실시하였다.
(3) 데이터의 분포를 확인하고 주요 변수 간의 상관관계를 분석하였다.
(4) 고객 이탈 원인을 파악하기 위해 분석 계획을 수립하였다.
(5) 공공데이터포털에서 인구 통계 데이터를 다운로드하고, 설문조사를 통해 추가 데이터를 수집하였다.
(6) 분석 결과를 시각화하여 보고서를 작성하고, 경영에게 발표하였다.

[보기] ① 문제의 정의 및 계획 ② 데이터 수집 ③ 데이터 정제 및 전처리 ④ 데이터 탐색 ⑤ 데이터 분석 ⑥ 결과 보고

(1) ③ 데이터 정제 및 전처리
(2) ⑤ 데이터 분석
(3) ④ 데이터 탐색
(4) ① 문제의 정의 및 계획
(5) ② 데이터 수집
(6) ⑥ 결과 보고

# %%
[04~07] 다음은 판다스의 시리즈와 데이터프레임에 관한 내용이다. 각 문제에서 요구하는 파이썬 코드를 작성하시오.
    단, import pandas as pd를 사전에 실행했다고 가정한다.
04 혈액형 'A', 'B', 'O', 'AB'를 blood 변수에 시리즈 형태로 저장하시오.
05 print()를 사용하여 앞에서 생성한 blood의 두 번째 값('B')을 출력하시오.
06 아래 제시된 2차원 배열을 데이터프레임 df에 저장하시오.
07 print()를 사용하여 앞에서 생성한 df의 2행 2열의 값(12)을 출력하시오.

# %%
[08~12] 다음과 같이 3명의 학생과 4개 과목 성적 데이터를 이용해 판다스 데이터프레임을 생성한 뒤, 아래에 이어지는 문제를 해결하시오.
08 학생들의 이름을 출력하시오.
09 과목 이름을 출력하시오.
10 절대 위치 인덱스 기준 0행 2열의 값을 출력하시오.
11 Jane의 영어(ENG) 성적을 출력하시오.
12 다음 명령문을 실행하여 결과를 확인하고 해당 결과가 나오는 이유를 설명하시오.

# %%
Chapter 03 시리즈 1차원 배열 다루기
[01~18] 다음은 어느 보험회사의 8개 영업팀(A~H)이 달성한 1분기 매출 실적 데이터이다. 아래에 이어지는 문제를 해결하기 위한 파이썬 코드를 작성하시오. 단, import pandas as pd를 사전에 실행했다고 가정한다.
01 매출 실적 데이터를 판다스 시리즈 sales에 저장하고, 팀 이름을 인덱스로 설정한 후 내용을 출력하시오.
02 sales의 배열 길이(값이 개수)를 출력하시오.
03 인덱스 기준 2번째 팀의 매출액을 출력하시오.
04 F팀의 매출액을 출력하시오.
05 인덱스 기준 3~5번째 팀의 매출액을 출력하시오.
06 A, B, D팀의 매출액을 출력하시오.
07 매출액이 600 이상인 팀들의 이름과 매출액을 출력하시오.
08 매출액이 500 미만이거나 700을 초과하는 팀들의 이름과 매출액을 출력하시오.
09 B팀보다 매출액이 많은 팀들의 이름과 매출액을 출력하시오.
10 매출액이 600 미만인 팀들의 이름을 출력하시오.
11 각 팀의 매출액이 20% 증가했을 때의 매출액을 출력하시오.
12 매출액이 600 미만인 팀들의 매출액만 20% 올린 결과를 출력하시오.
13 8개 팀의 매출액 평균, 합계, 표준편차를 출력하시오.
14 H팀의 매출액을 800으로 변경하고, 변경 여부를 확인하시오.
15 A팀과 C팀의 매출액을 각각 810, 820으로 변경하고, 변경 여부를 확인하시오.
16 신생 팀 J의 매출액 400을 sales에 추가하시오.
17 J팀의 매출액 정보를 삭제하시오.
18 slaes의 내용을 slaes2에 복사한 후, slaes2의 매출액을 500씩 올리고 slaes와 slaes2의 내용을 비교하시오.

# %%
Chapter 04 데이터프레임으로 2차원 배열 다루기
[01~20] 타이타닉호 승객 데이터를 저장한 titanic 데이터셋을 대상으로 분석을 진행하려고 한다. 주요 컬럼에 대한 설명은 다음과 같다. 표 오른쪽에 있는 코드를 실행하여 데이터를 준비한 후, 아래에 이어지는 문제를 해결하시오.
01 데이터셋에 대한 정보를 확인하시오. 몇 개의 행과 몇 개의 컬럼으로 구성되어 있는가?
02 데이터셋의 컬럼 이름을 출력하시오.
03 titanic 데이터셋에서 앞쪽 10개의 행을 출력하시오.
04 선실은 몇 개의 등급으로 구성되어 있는지 확인하시오.
05 인덱스 기준 2행 4열의 값을 확인하시오.
06 앞쪽 5명의 탑승객에 대해 선실, 성별, 나이, 생존 여부를 출력하시오.
07 나이가 60세 이상인 승객의 성별, 나이, 생존 여부를 출력하시오.
08 나이가 10세 미만인 여성 승객의 나이, 생존 여부를 출력하시오.

# %%
Chapter 05 단일 변수 데이터의 탐색
[01~09] seaborn 라이브러리에 포함된 tips 데이터셋은 레스토랑 이용 고객의 관련 데이터를 저장하고 있다. 다음 코드를 실행한 후, 아래에 이어지는 문제를 해결하시오.
01 tips 데이터셋을 불러와 df에 저장한 후, day 컬럼의 값을 day에 저장하시오. day는 고객의 레스토랑 방문 요일 데이터이다.
02 day의 내용과 자료형(type)을 확인하시오.
03 day에 포함된 값들에 대해 도수 분포를 계산하여 fd에 저장하시오.
04 fd를 이용하여 요일별 방문자 수 비율을 출력하시오.
05 fd를 이용하여 요일별 방문자 수를 세로 방향 막대그래프로 나타내시오.
06 fd를 이용하여 요일별 방문자 수를 가로 방향 막대그래프로 나타내시오. 단, 막대의 색은 빨간색으로 하시오.
07 fd를 이용하여 요일별 방문자 수를 원그래프로 나타내시오.
08 문제 01의 df에서 smoker 컬럼에는 레스토랑 방문 고객의 흡연 여부 데이터가 저장되어 있다. 흡연 여부별 고객수를 막대그래프로 나타내시오.
09 문제 01의 df에서 time 컬럼에는 레스토랑 고객의 방문 시간대가 저장되어 있다. 방문 시간대별 고객 비율을 원그래프로 나타내시오.

# %%
Chapter 06 연습문제 (펭귄 및 대기 질 데이터)
[01~04] 펭귄 데이터셋 준비 및 산점도/상관계수 분석
01 부리의 가로 길이와 세로 길이에 대한 산점도를 작성하시오.
02 부리의 가로 길이와 세로 길이에 대한 상관계수를 구하시오.
03 부리의 가로 길이와 날개 길이에 대한 산점도를 작성하시오.
04 부리의 가로 길이와 날개 길이에 대한 상관계수를 구하시오.

# %%
[05~09] 펭귄 종 및 성별 특징 분석
05 펭귄의 종에는 어떤 종류가 있는지 확인하시오.
06 부리의 가로 길이와 세로 길이에 대한 산점도를 작성하되, 종별로 점의 색을 다르게 표시하시오.
07 문제 06의 결과를 바탕으로 펭귄의 종별 특징을 설명하시오.
08 부리의 가로 길이와 날개 길이에 대한 산점도를 작성하되, 성별로 점의 색을 달리하여 표시하시오.
09 부리의 가로 길이와 날개 길이에 대해 관찰 가능한 성별 특징을 설명하시오.

# %%
[10~12] 다중 산점도 및 상관계수
10 penguins 데이터셋에서 숫자형 컬럼들에 대해 다중 산점도를 작성하시오.
11 penguins 데이터셋에서 숫자형 컬럼들의 다중 상관계수를 구하고, 이를 출력하시오.
12 문제 11의 결과에서 가장 상관계수가 큰 두 변수를 찾으시오.

# %%
[13~18] 대기의 질(airquality) 데이터 분석
13 오존농도(Ozone)와 일사량(Solar.R)에 대해 산점도를 작성하시오.
14 오존농도(Ozone)와 일사량(Solar.R)에 대한 상관계수를 구하시오.
15 오존농도(Ozone)와 일사량(Solar.R)에 대해 산점도를 작성하되, 월별로 점의 색을 다르게 표시하시오.
16 오존농도, 일사량, 풍속(Wind), 기온(Temp)에 대해 다중 산점도를 작성하시오.
17 월(Month)과 가장 상관계수가 큰 변수를 찾으시오.
18 오존농도, 일사량, 풍속, 기온에 대해 5월과 9월의 상관계수 변화가 가장 큰 변수의 조합을 구하시오.

# %%
Chapter 07 연습문제 (Planets 및 결측치/그룹화 전처리)
[01~10] planets 데이터셋 전처리
01 각 컬럼별 결측값의 개수를 출력하시오.
02 데이터셋 전체에서 결측값의 총 개수를 출력하시오.
03 mass, distance 컬럼을 제외한 후, 결측값이 없는 행들만 추출하여 df_clean에 저장하시오.
04 orbital_period 컬럼의 결측값을 추정하여 채운 후, 결측값 추정 전과 추정 후의 평균값을 비교하여 출력하시오.
05 orbital_period 컬럼에서 Z-score를 특이값을 찾아 출력하시오.
06 distance 컬럼에서 IQR을 이용하여 특이값을 찾아 출력하시오.
07 문제 06에서 구한 특이값을 제거한 데이터를 dist_clean에 저장하고, 제거 전후의 평균값을 비교하여 출력하시오.
08 df의 내용을 mass 컬럼 기준으로 내림차순 정렬하여 출력하시오.
09 df의 mass 컬럼 값을 내림차순 기준으로 순위를 계산하여 새로운 rank 컬럼에 저장한 후 df의 내용을 출력하시오.
10 데이터프레임 df에서 임의로 20개의 행을 추출하여 df20에 저장하고 내용을 출력하시오(표본 추출 시 random_state=123 사용).

# %%
[11~16] 펭귄 데이터셋 그룹화 및 집계
11 펭귄의 종을 기준으로 부리의 가로 길이와 세로 길이의 평균을 출력하시오.
12 펭귄의 성별을 기준으로 몸무게와 날개 길이의 최댓값을 출력하시오.
13 펭귄의 종과 성별을 기준으로 부리의 가로 길이와 세로 길이의 평균을 출력하시오.
14 펭귄의 종과 성별을 기준으로 빈도수를 집계하여 출력하시오.
15 펭귄의 종과 서식지를 기준으로 평균 날개 길이를 집계하여 출력하시오.
16 펭귄의 종과 성별을 기준으로 평균 몸무게를 집계하여 출력하시오.

# %%
[17~20] 국가코드 및 무역국가 데이터 병합 및 집계
17 국가코드 데이터셋과 무역국가 데이터셋을 병합하여 df_merge에 저장하시오.
18 무역 대상 국가명과 수출 품목을 출력하시오.
19 국가별 수출 금액과 수입 금액을 집계하여 출력하시오.
20 수출 금액과 수입 금액이 가장 많은 상위 5개 국가의 수출 금액, 수입 금액, 합계 금액을 출력하시오.
