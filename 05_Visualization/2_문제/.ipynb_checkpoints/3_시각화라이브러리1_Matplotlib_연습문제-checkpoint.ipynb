# %% [markdown]
# # Matplotlib

# %%
import numpy as np
import pandas as pd
import json
import folium

print(f'numpy : {np.__version__}, pandas : {pd.__version__}, json:{json.__version__}, folium:{folium.__version__}')
# Out:
# numpy : 2.5.2, pandas : 3.0.5, json:2.0.9, folium:0.20.0

# %% [markdown]
# ## 실습문제1.

# %% [markdown]
# #### 미세먼지 측정 데이터에 대한 선그래프 작성하기
#
# - 2001년~2019년까지 미세먼지 측정 데이터
# - 데이터 파일 : 'fine_dust.xlsx'
# - 자료출처 : AirKorea(https://www.airkorea.or.kr/web/ )

# %% [markdown]
# #### 1) 데이터 읽기

# %%
data = pd.read_excel('data/fine_dust.xlsx')
data.tail(2)
# Out:
#           area  2001  2002  2003  2004  2005  2006  2007  2008  2009  2010  \
# 12  Gyeongsang  51.0  55.0  52.0  58.0  54.5    54    52  50.5  47.5  46.5
# 13        Jeju  46.0  45.0  37.0  43.0  45.0    49    44  43.0  42.0  48.0
#
#     2011  2012  2013  2014  2015  2016  2017  2018  2019
# 12    47  43.5  48.5  48.5  45.5  42.5  41.5  42.5  38.5
# 13    42  34.0  40.0  47.0  44.0  41.0  37.0  35.0  35.0

# %% [markdown]
# #### 2) 데이터 파악 : 변수정보 등

# %%
data.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 14 entries, 0 to 13
# Data columns (total 20 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   area    14 non-null     str
#  1   2001    14 non-null     float64
#  2   2002    14 non-null     float64
#  3   2003    14 non-null     float64
#  4   2004    14 non-null     float64
#  5   2005    14 non-null     float64
#  6   2006    14 non-null     int64
#  7   2007    14 non-null     int64
#  8   2008    14 non-null     float64
#  9   2009    14 non-null     float64
#  10  2010    14 non-null     float64
#  11  2011    14 non-null     int64
#  12  2012    14 non-null     float64
#  13  2013    14 non-null     float64
#  14  2014    14 non-null     float64
#  15  2015    14 non-null     float64
#  16  2016    14 non-null     float64
#  17  2017    14 non-null     float64
#  18  2018    14 non-null     float64
#  19  2019    14 non-null     float64
# dtypes: float64(16), int64(3), str(1)
# ...

# %% [markdown]
# #### 3) 서울의 2001년~2019년까지 미세먼지 변화를 선그래프로 그리기¶

# %% [markdown]
# #### 4) 2018년 지역별 미세먼지 수치에 대한 선그래프 그리기

# %% [markdown]
# #### 5) 2016년~2019년까지 지역별 미세먼지 변화에 대한 선그래프를 한 플롯에 그리기

# %% [markdown]
# #### 6) 2016년~2019년까지 지역별 미세먼지 변화에 대한 선그래프를 subplot(s)으로 각각 그리기

# %% [markdown]
# ---

# %% [markdown]
# ## 실습문제2.

# %% [markdown]
# #### 시도별 전출입에 대한 이동자수 변화에 대한 선그래프 그리기
#
# - 1970년부터 2022년까지의 시도별 전출/전입 이동자 현황
# - 데이터 파일 : '전출지전입지_시도별이동자수_2022.xlsx'
# - 자료출처 : 「국내인구이동통계」, 통계청
# - https://kosis.kr/statHtml/statHtml.do?orgId=101&tblId=DT_1B26003_A01&conn_path=I3

# %% [markdown]
# #### 1) 데이터 읽기

# %% [markdown]
# #### 2) 데이터 파악 : 변수정보, 결측치 확인 등

# %% [markdown]
# #### 3) 결측치 처리
#
# - '전출지별'컬럼의 결측치 대체

# %% [markdown]
# #### 4) 컬럼 이름 변경
# - '전입지별'을 '전입지'로

# %% [markdown]
# #### 5) '전출지별'컬럼이 서울인 데이터만 추출하여 df_seoul로 저장하고, '전출지별'컬럼을 삭제

# %% [markdown]
# #### 6) 5)에서 생성한 데이터프레임을 이용하여 전입지가 경기도인 데이터에 대하여 연도별 전입지 추이를 나타내는 선그래프 그리기

# %% [markdown]
# #### 7) 서울에서 전출하여 충남, 경북, 강원으로 전입한 데이터에 대하여 연도별 추이를 나타내는 선그래프 그리기

# %% [markdown]
# #### 8) 서울에서 타지역(충청남도, 경상북도, 강원도, 전라남도)으로의 인구 이동 추이에 대한 영역 그래프 그리기

# %% [markdown]
# ----
