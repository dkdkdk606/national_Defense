# %% [markdown]
# ## Open API 사용 실습문제

# %% [markdown]
# [문제] 경기데이터드림 사이트의 공중화장실 데이터를 API를 통해 수집하고 csv 파일로 저장하기

# %% [markdown]
# #### 필요한 모듈 임포트

# %%
import requests
from urllib.request import urlopen
from bs4 import BeautifulSoup
import pandas as pd

# %% [markdown]
# #### 경기도 공중화장실 데이터 수집

# %% [markdown]
# - 경기데이터드림 사이트 : https://data.gg.go.kr/portal/mainPage.do
# - 데이터 다운로드 링크 주소
# https://data.gg.go.kr/portal/data/service/selectServicePage.do?infId=GW6U772M6045H11Q799612585601&infSeq=1

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### 참고. OpenAPI를 활용한 데이터 수집 단계
#
# 1. Open API 이용방법 확인
# 2. 인증키 발급신청
# 3. 인증키 메일확인
# 4. 데이터 수집

# %% [markdown]
# #### API 요청을 위한 url과 요청변수 지정
#
# - 요청페이지 url :  https://openapi.gg.go.kr/Publtolt?
#
# - 요청변수(parameters)
#     - KEY : 인증키
#     - Type : 호출문서(xml 기본)
#     - pindex : 페이지 위치(기본값 : 1)
#     - psize : 페이지당 요청숫자(기본값 :100)

# %%
SERVICE_KEY

# %% [markdown]
# #### API 요청

# %% [markdown]
# #### parsing

# %% [markdown]
# #### 데이터 추출 및 데이터 프레임으로 저장

# %% [markdown]
# ----
