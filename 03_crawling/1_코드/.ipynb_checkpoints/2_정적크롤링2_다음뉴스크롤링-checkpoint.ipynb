# %% [markdown]
# # 정적크롤링 실습2. 뉴스기사 크롤링

# %%
import requests
from urllib.request import urlopen
from bs4 import BeautifulSoup

# %% [markdown]
# #### 크롤링 단계
#
# 1. 크롤링하려는 HTML 페이지의 구조와 코드 살펴보기
#     - F12 (구글 크롬 개발자도구) : URL주소, 태그 확인
# 2. 문서 내용 읽어오기 :
#     - html = urllib.request.urlopen(URL주소).read()
# 3. 원하는 내용 추출하기(parsing)
#     - soup = bs4.BeautifulSoup(html, 'html.parser')
#     - soup.find_all(찾아낼태그)
#     - 동일한 태그가 여러 개인 경우 class 속성 사용

# %% [markdown]
# ### 1. 뉴스 머리기사 제목 크롤링

# %% [markdown]
# - 목적 : 다음 뉴스의 헤드라인 뉴스 제목 크롤링 (https://www.daum.net/)

# %% [markdown]
# #### 단계1. HTML 페이지 살펴보기

# %% [markdown]
# #### 단계2. 문서 내용 읽어오기

# %% [markdown]
# #### 단계3. 원하는 내용 추출하기(parsing)
#
# : 뉴스 머리기사 제목 추출
#
# - 머리기사 제목에 해당하는 태그와 속성값 확인
# - 개발자도구의 콘솔(console)창을 기사의 제목 일부를 입력하여 검색

# %% [markdown]
# #### 반복문으로 기사 제목 모두 추출하기

# %% [markdown]
# ### 2. 뉴스 기사 하이퍼링크 주소 추출하기

# %% [markdown]
# - 뉴스기사 페이지로 이동하는 \<a\>태그의 하이퍼링크 주소 가져오기

# %% [markdown]
# #### 문제. 다음 뉴스 머리기사의 언론사, 제목, 링크를 크롤링하고 그 결과를 데이터프레임으로 생성하기

# %%
# 모듈 임포트
from urllib import request
from bs4 import BeautifulSoup
import pandas as pd

# 단계1. 페이지 읽기
url = 'https://news.daum.net'
html = request.urlopen(url).read()

# 단계2. 파싱
soup = BeautifulSoup(html, 'html.parser')

# 뉴스 카드 전체 영역(또는 개별 뉴스 링크 태그)을 기준으로 반복문 돌리기
# 제공해주신 HTML에 따르면 각 뉴스는 a.item_newsheadline2 로 감싸져 있습니다.
news_items = soup.select('a.item_newsheadline2')

title_list = [item in news_tiems]
media_list = []
link_list = []

for item in news_items:
    # 각 뉴스 박스 안에서 제목 추출
    title_elem = item.select_one('strong.tit_txt')
    # 각 뉴스 박스 안에서 언론사 추출
    media_elem = item.select_one('span.txt_info')
    
    # 요소가 존재하는 경우에만 리스트에 추가
    if title_elem and media_elem:
        title_list.append(title_elem.text.strip())
        media_list.append(media_elem.text.strip())
        link_list.append(item.get('href', ''))

# 수집된 데이터 개수 확인
print(f"수집된 뉴스 건수: {len(title_list)}")

# 단계3. 데이터프레임으로 변환 & 파일 저장
news_df = pd.DataFrame({
    '언론사': media_list, 
    '뉴스제목': title_list, 
    '기사링크': link_list
})

print(news_df)

# 파일 저장 (폴더가 없다면 에러가 날 수 있으니 참고하세요)
# news_df.to_csv('daum_headline_news.csv', index=False, encoding='utf-8-sig')


'''
# 단계1. 페이지 읽기
url = 'https://news.daum.net'
html = request.urlopen(url).read()

# 단계2. 파싱
soup = BeautifulSoup(html, 'html.parser')

main_news = soup.select_one('ul.list_newaheadline2')

titles = main_news.select('strong.tit_txt')
medias = main_news.select('span.txt_info')
links = main_news.select('a.item_newaheadline2')
medias = main_news.select('span.txt_info')            # 언론사
links = main_news.select('a.item_newaheadline2')      # 뉴스 상세페이지링크

title_list = [t.text for t in titles]
media_list = [m.text for m in medias[::2]]
link_list = [a['href'] for a in links]

# 단계3. 데이터프레임으로 변환 & 파일 저장
news_df = pd.DataFrame(data = {'언론사': media_list, '뉴스제목':title_list, '기사링크':link_list})
news_df.to_csv('crawl_data/daum.headline_news.csv', index=False)
news_df


'''
# Out:
# 수집된 뉴스 건수: 16
#        언론사                                               뉴스제목  \
# 0      YTN            북한 미사일에 미 "동맹 방어 전념"...대이란 작전엔 동맹 참여 압박
# 1     연합뉴스              8월 중순 수출 56%↑…반도체 비중 47.2%, 역대 최고(종합)
# 2    아시아경제                 베선트 '바이백 총력전'…40조달러 부채에 금리 재상승(종합)
# 3   파이낸셜뉴스               AI데이터센터 주민 불만, 美 중간선거 쟁점으로[글로벌AI브리핑]
# 4    아시아경제           사상 최고치 찍었는데 전문가들 "더 오른다"…AI 시대 주목받는 원자재는
# 5   파이낸셜뉴스  "8·13 대책, 그래서 대출 나온다고?"...2030 '영끌' 전략은[집 나와라 ...
# 6    헤럴드경제             與복기왕 “지역주택조합·리모델링 규제 함께 푼다…도심 주택공급 속도”
# 7      MBN                     트럼프 '러브콜'에도 미사일 10여 발⋯북한은 또 침묵
# 8     서울경제        SK하이닉스, 40조+10조 자사주 추가 매입…노사 합의로 ‘주주가치 선순환’
# 9     한국일보           마라에 빠져 직장 박차고 떠난 중국... 부산 '성지' 된 라라관의 비밀
# 10    조선일보              “5남매 엄마 겁났지만… 힘든 건 곱하기 2, 행복은 곱하기 10”
# 11    부산일보  [인터뷰] 이현태 금정산국립공원사무소장 “금정산, 이용하는 산에서 함께 지켜가는 산으로”
# 12    시사IN              별 볼 일 없는 하루라고요? ‘벌 볼 일’은 많습니다! [사람IN]
# 13    중앙일보                  “보수는 무식한데 진보는…” 1020 남성들이 극우 된 까닭
# 14     뉴시스                                 [그래픽] 최근 북한 미사일 발사
# 15    시사IN                                  20년 [굽시니스트 시사 만화]
#
#                                       기사링크
# 0   https://v.daum.net/v/20260821093709562
# 1   https://v.daum.net/v/20260821093153310
# 2   https://v.daum.net/v/20260821091045472
# 3   https://v.daum.net/v/20260821090929425
# 4   https://v.daum.net/v/20260821081927026
# 5   https://v.daum.net/v/20260821080209723
# 6   https://v.daum.net/v/20260821075353552
# 7   https://v.daum.net/v/20260821071850013
# 8   https://v.daum.net/v/20260821070144755
# 9   https://v.daum.net/v/20260821043141579
# 10  https://v.daum.net/v/20260821003915584
# 11  https://v.daum.net/v/20260820175350512
# 12  https://v.daum.net/v/20260820075440211
# 13  https://v.daum.net/v/20260820050255546
# 14  https://v.daum.net/v/20260821093452453
# 15  https://v.daum.net/v/20260821093041253
# "\n# 단계1. 페이지 읽기\nurl = 'https://news.daum.net'\nhtml = request.urlopen(url).read()\n\n# 단계2. 파싱\nsoup = BeautifulSoup(html, 'html.parser')\n\nmain_news = soup.select_one('ul.list_newaheadline2')\n\ntitles = main_news.select('strong.tit_txt')\nmedias = main_news.select('span.txt_info')\nlinks = main_news.select('a.item_newaheadline2')\nmedias = main_news.select('span.txt_info')            # 언론사\nlinks = main_news.select('a.item_newaheadline2')      # 뉴스 상세페이지링크\n\ntitle_list = [t.text for t in titles]\nmedia_list = [m.text for m in medias[::2]]\nlink_list = [a['href'] for a in links]\n\n# 단계3. 데이터프레임으로 변환 & 파일 저장\nnews_df = pd.DataFrame(data = {'언론사': media_list, '뉴스제목':title_list, '기사링크':link_list})\nnews_df.to_csv('crawl_data/daum.headline_news.csv', index=False)\nnews_df\n\n\n"

# %% [markdown]
# ------

# %% [markdown]
# ### 3. 기사제목과 내용 한꺼번에 추출하기

# %% [markdown]
# #### 기사제목과 내용이 있는 태그 확인

# %%
# 뉴스제목 : <h3 class='tit_view'>
# 기자정보 : <span class='txt_info'>
# 작성일자 : <span class='num_date'>
# 뉴스내용 : <div class='article_view'>

# %%
url = link_list[0]
html = request.urlopen(url).read()
soup = BeautifulSoup(html, 'html.parser')
title = soup.select_one('h3.tit_view').text
author = soup.select_one('span.txt_info').text
date = soup.select_one('span.num_date').text
article = soup.select_one('div.article_view').text

# %%
title, author, date
# Out:
# ('북한 미사일에 미 "동맹 방어 전념"...대이란 작전엔 동맹 참여 압박', '홍상희', '2026. 8. 21. 09:37')

# %%
print(article)
# Out:
# [앵커]
# 북한의 탄도미사일 도발에 미국은 위협이 안 된다고 평가하면서 동맹국 방어에 전념하고 있다고 강조했습니다.
# 대이란 경제 고립 작전에 대해서는 미국의 편인지 아닌지 선택하라며 동맹국에 동참을 압박했습니다.
# 워싱턴 홍상희 특파원입니다.
# [기자]
# 북한의 단거리 탄도미사일 발사 하루 만에 미 태평양사령부가 성명을 발표했습니다.
# 미 태평양사령부는 북한의 미사일 발사가 미국이나 동맹국들에게 즉각적인 위협이 되지 않는다고 밝혔습니다.
# 또 미국 본토와 동맹국 방어에 전념하고 있다고 덧붙였습니다.
# 도널드 트럼프 대통령이 한미군사훈련까지 대폭 축소하며 대화의 손길을 내민 직후 북한이 미사일로 응답하자 동맹 방어를 다시 강조한 겁니다.
# 대이란 전쟁에선 동맹국을 다시 압박하고 있습니다.
# 스콧 베선트 미 재무장관은 오는 24일 대이란 경제압박 계획을 공개하겠다며 세계 역사상 가장 강력하게 공조한 작전이 될 것이라고 예고했습니다.
# 그러면서 이제 동맹국이 결정을 내려야 할 시점이라면서 미국의 편인지, 아니면 미국에 맞설 것인지 양자택일 하라며 동참을 압박했습니다.
# 베선트 장관은 또 대이란 경제제재가 대규모 확전으로 이어질 가능성은 작다면서 이번 작전으로 유가가 내려갈 거라고 주장했습니다.
# [스콧 베선트 / 미국 재무부 장관 : 우리가 발표한 건 경제적 조치에 관한 것입니다. 그 경제적 조치로 인해 유가가 더 빨리 내려갈 것이라고 생각합니다.]
# 앞서 트럼프 대통령은 동맹국 뿐 아니라 이란과 거래하는 제3국도 막대한 경제적 대가를 치르게 될 거라고 경고했습니다.
# [도널드 트럼프 / 미국 대통령(현지시간 19일) : 우리가 제재할 수 있는 수단이 있습니다. 매우 강력한 제재 수단이 마련되어 있으니, 어떻게 될지 지켜보겠습니다]
# 트럼프 행정부의 동맹국에 대한 오락가락한 태도에 정치권의 비판도 이어지고 있습니다. 한국계 데이브 민 하원의원은 트럼프 대통령이 가장 가까운 동맹국을 소외시키고 평화를 위태롭게 하고 있다고 지적했습니다.
# 워싱턴에서 YTN 홍상희입니다.
# 촬영 : 강연오
# YTN 홍상희 (san@ytn.co.kr)
# ※ '당신의 제보가 뉴스가 됩니다'
# [카카오톡] YTN 검색해 채널 추가
# [전화] 02-398-8585
# [메일] social@ytn.co.kr
# [저작권자(c) YTN 무단전재, 재배포 및 AI 데이터 활용 금지]

# %%
soup.select('[dmcf-ptype="general"]')
# Out:
# [<p contents-hash="f110e1942b18ea1f5683d501992c682c20a2f00c498747500e8a4cfd6da3e738" dmcf-pid="HbIWaBcnTU" dmcf-ptype="general">[앵커] </p>,
#  <p contents-hash="18b25deebd146afe0521e4dc11f5b517592c0b4ac821e2ac13b94e40eddc9ebd" dmcf-pid="XKCYNbkLSp" dmcf-ptype="general">북한의 탄도미사일 도발에 미국은 위협이 안 된다고 평가하면서 동맹국 방어에 전념하고 있다고 강조했습니다. </p>,
#  <p contents-hash="70a06824067874195d4a09ed5f429608df681586c68194bfed8efc92664f8e63" dmcf-pid="Z9hGjKEoS0" dmcf-ptype="general">대이란 경제 고립 작전에 대해서는 미국의 편인지 아닌지 선택하라며 동맹국에 동참을 압박했습니다. </p>,
#  <p contents-hash="8939808f955be0e74a0e736e31e082d9f1a0f0a690ec91208a5af309b8a5d86c" dmcf-pid="5kb65c3GT3" dmcf-ptype="general">워싱턴 홍상희 특파원입니다. </p>,
#  <p contents-hash="7d6532a3ff72e6e61d28713c15e4ad75a3f8e21259fbcf585fa2e73bce76e203" dmcf-pid="1EKP1k0HTF" dmcf-ptype="general">[기자] </p>,
#  <p contents-hash="2ee168238f6adacdd31dcd6eee82316c110ebff51282363016dbcb7aab73cab8" dmcf-pid="tD9QtEpXyt" dmcf-ptype="general">북한의 단거리 탄도미사일 발사 하루 만에 미 태평양사령부가 성명을 발표했습니다. </p>,
#  <p contents-hash="c357d9e84558045ca1e4aee076aa4311ea5dd3d86c7736034b56f69e4c6df28b" dmcf-pid="Fw2xFDUZC1" dmcf-ptype="general">미 태평양사령부는 북한의 미사일 발사가 미국이나 동맹국들에게 즉각적인 위협이 되지 않는다고 밝혔습니다. </p>,
#  <p contents-hash="5021625cc96236b71e360cc1e763012d557f5a8542dfa74519a6f563de5a8380" dmcf-pid="3rVM3wu5T5" dmcf-ptype="general">또 미국 본토와 동맹국 방어에 전념하고 있다고 덧붙였습니다. </p>,
#  <p contents-hash="f812b04226c0243291fff3b67f86fc1ba29ec11faeb7fb4dce5d8e2d8e6a2c41" dmcf-pid="0mfR0r71lZ" dmcf-ptype="general">도널드 트럼프 대통령이 한미군사훈련까지 대폭 축소하며 대화의 손길을 내민 직후 북한이 미사일로 응답하자 동맹 방어를 다시 강조한 겁니다. </p>,
#  <p contents-hash="88b9bc1fc281e3f3d1121250b2411b41948447aff5cb8ff571d0db9a62463023" dmcf-pid="ps4epmzthX" dmcf-ptype="general">대이란 전쟁에선 동맹국을 다시 압박하고 있습니다. </p>,
#  <p contents-hash="a94520ec7233078ece13bf5f409eac0a2e3bef3c4042acb0a3403c80797de164" dmcf-pid="UO8dUsqFTH" dmcf-ptype="general">스콧 베선트 미 재무장관은 오는 24일 대이란 경제압박 계획을 공개하겠다며 세계 역사상 가장 강력하게 공조한 작전이 될 것이라고 예고했습니다. </p>,
#  <p contents-hash="5933b985a956c7be9727be7d4302a03b637cd79a860789c3e7c2a2edc399b5ed" dmcf-pid="uI6JuOB3TG" dmcf-ptype="general">그러면서 이제 동맹국이 결정을 내려야 할 시점이라면서 미국의 편인지, 아니면 미국에 맞설 것인지 양자택일 하라며 동참을 압박했습니다. </p>,
#  <p contents-hash="8aff0701ff58e9ec083801cdba024b4a030fe213992915b83ec4457ee9277a31" dmcf-pid="7D9QtEpXCY" dmcf-ptype="general">베선트 장관은 또 대이란 경제제재가 대규모 확전으로 이어질 가능성은 작다면서 이번 작전으로 유가가 내려갈 거라고 주장했습니다. </p>,
#  <p contents-hash="b5348cb67a11f0cc3fea6ac3ee529c8bd39f50cee3b683deda031dc0274bb415" dmcf-pid="zw2xFDUZlW" dmcf-ptype="general">[스콧 베선트 / 미국 재무부 장관 : 우리가 발표한 건 경제적 조치에 관한 것입니다. 그 경제적 조치로 인해 유가가 더 빨리 내려갈 것이라고 생각합니다.] </p>,
#  <p contents-hash="47434a29f66d49c4460a7c88f062de70112b9389d501c80c5c1eab8013e663d3" dmcf-pid="qrVM3wu5hy" dmcf-ptype="general">앞서 트럼프 대통령은 동맹국 뿐 아니라 이란과 거래하는 제3국도 막대한 경제적 대가를 치르게 될 거라고 경고했습니다. </p>,
#  <p contents-hash="2d6a20331fe72c8dd8c5cfdf5040164872d72b83951d1febb7f7329a85828cc1" dmcf-pid="BmfR0r71vT" dmcf-ptype="general">[도널드 트럼프 / 미국 대통령(현지시간 19일) : 우리가 제재할 수 있는 수단이 있습니다. 매우 강력한 제재 수단이 마련되어 있으니, 어떻게 될지 지켜보겠습니다] </p>,
#  <p contents-hash="003481be6114491bdc9d6520f838c03d048b2539a23ec456e9ab058ea7414dbd" dmcf-pid="bs4epmzthv" dmcf-ptype="general">트럼프 행정부의 동맹국에 대한 오락가락한 태도에 정치권의 비판도 이어지고 있습니다. 한국계 데이브 민 하원의원은 트럼프 대통령이 가장 가까운 동맹국을 소외시키고 평화를 위태롭게 하고 있다고 지적했습니다. </p>,
#  <p contents-hash="814c49eea05a4198e5ec260a1eac678b8df0ebd96b705c234eef9fb19ddb0d57" dmcf-pid="KO8dUsqFSS" dmcf-ptype="general">워싱턴에서 YTN 홍상희입니다. </p>,
#  <p contents-hash="e8b1d5b9bcabf9e8a2af748468f912f4b22e700222dcf5a9856bab2e0f3de3cf" dmcf-pid="9I6JuOB3Wl" dmcf-ptype="general">촬영 : 강연오 </p>,
#  <p contents-hash="8cd8cf914538d1b7868b6510bac33576f1907d10726e000eaceb9b1cf8fe380d" dmcf-pid="2CPi7Ib0yh" dmcf-ptype="general">YTN 홍상희 (san@ytn.co.kr)</p>,
#  <p contents-hash="9d20dd88e163277662ec52de1d16d30713cd636a8e3671ebad9f45b0ece2ddfa" dmcf-pid="VhQnzCKplC" dmcf-ptype="general">※ '당신의 제보가 뉴스가 됩니다' </p>,
#  <p contents-hash="025f701490cc942f3fc84a05e2eb7aa9230109ab1e9d8f63eb3e81f9f8a55b8c" dmcf-pid="fSMoBl2ulI" dmcf-ptype="general">[카카오톡] YTN 검색해 채널 추가 </p>,
#  <p contents-hash="f8285fb1cf4c14289a4410950476c85542c122266b7e33649e5eb9decc432933" dmcf-pid="4vRgbSV7vO" dmcf-ptype="general">[전화] 02-398-8585 </p>,
#  <p contents-hash="f0a6c686a290d91d3045290c3d1bba47753ce6ea5e7f9b0acecef9d6075baa07" dmcf-pid="8TeaKvfzvs" dmcf-ptype="general">[메일] social@ytn.co.kr</p>,
#  <p contents-hash="d37a8ac57510cdb9e7e0a3411b5868010900d5fb740e5908c8e6e3c6cecc236a" dmcf-pid="6ydN9T4qlm" dmcf-ptype="general">[저작권자(c) YTN 무단전재, 재배포 및 AI 데이터 활용 금지]</p>]

# %%
[art.get_text().strip() for art in soup.select('[dmcf-ptype="general"]')]
# Out:
# ['[앵커]',
#  '북한의 탄도미사일 도발에 미국은 위협이 안 된다고 평가하면서 동맹국 방어에 전념하고 있다고 강조했습니다.',
#  '대이란 경제 고립 작전에 대해서는 미국의 편인지 아닌지 선택하라며 동맹국에 동참을 압박했습니다.',
#  '워싱턴 홍상희 특파원입니다.',
#  '[기자]',
#  '북한의 단거리 탄도미사일 발사 하루 만에 미 태평양사령부가 성명을 발표했습니다.',
#  '미 태평양사령부는 북한의 미사일 발사가 미국이나 동맹국들에게 즉각적인 위협이 되지 않는다고 밝혔습니다.',
#  '또 미국 본토와 동맹국 방어에 전념하고 있다고 덧붙였습니다.',
#  '도널드 트럼프 대통령이 한미군사훈련까지 대폭 축소하며 대화의 손길을 내민 직후 북한이 미사일로 응답하자 동맹 방어를 다시 강조한 겁니다.',
#  '대이란 전쟁에선 동맹국을 다시 압박하고 있습니다.',
#  '스콧 베선트 미 재무장관은 오는 24일 대이란 경제압박 계획을 공개하겠다며 세계 역사상 가장 강력하게 공조한 작전이 될 것이라고 예고했습니다.',
#  '그러면서 이제 동맹국이 결정을 내려야 할 시점이라면서 미국의 편인지, 아니면 미국에 맞설 것인지 양자택일 하라며 동참을 압박했습니다.',
#  '베선트 장관은 또 대이란 경제제재가 대규모 확전으로 이어질 가능성은 작다면서 이번 작전으로 유가가 내려갈 거라고 주장했습니다.',
#  '[스콧 베선트 / 미국 재무부 장관 : 우리가 발표한 건 경제적 조치에 관한 것입니다. 그 경제적 조치로 인해 유가가 더 빨리 내려갈 것이라고 생각합니다.]',
#  '앞서 트럼프 대통령은 동맹국 뿐 아니라 이란과 거래하는 제3국도 막대한 경제적 대가를 치르게 될 거라고 경고했습니다.',
#  '[도널드 트럼프 / 미국 대통령(현지시간 19일) : 우리가 제재할 수 있는 수단이 있습니다. 매우 강력한 제재 수단이 마련되어 있으니, 어떻게 될지 지켜보겠습니다]',
#  '트럼프 행정부의 동맹국에 대한 오락가락한 태도에 정치권의 비판도 이어지고 있습니다. 한국계 데이브 민 하원의원은 트럼프 대통령이 가장 가까운 동맹국을 소외시키고 평화를 위태롭게 하고 있다고 지적했습니다.',
#  '워싱턴에서 YTN 홍상희입니다.',
#  '촬영 : 강연오',
#  'YTN 홍상희 (san@ytn.co.kr)',
#  "※ '당신의 제보가 뉴스가 됩니다'",
#  '[카카오톡] YTN 검색해 채널 추가',
#  '[전화] 02-398-8585',
#  '[메일] social@ytn.co.kr',
#  '[저작권자(c) YTN 무단전재, 재배포 및 AI 데이터 활용 금지]']

# %%
article = '\n'.join([art.get_text().strip() for art in soup.select('[dmcf-ptype="general"]')])
print(article)
# Out:
# [앵커]
# 북한의 탄도미사일 도발에 미국은 위협이 안 된다고 평가하면서 동맹국 방어에 전념하고 있다고 강조했습니다.
# 대이란 경제 고립 작전에 대해서는 미국의 편인지 아닌지 선택하라며 동맹국에 동참을 압박했습니다.
# 워싱턴 홍상희 특파원입니다.
# [기자]
# 북한의 단거리 탄도미사일 발사 하루 만에 미 태평양사령부가 성명을 발표했습니다.
# 미 태평양사령부는 북한의 미사일 발사가 미국이나 동맹국들에게 즉각적인 위협이 되지 않는다고 밝혔습니다.
# 또 미국 본토와 동맹국 방어에 전념하고 있다고 덧붙였습니다.
# 도널드 트럼프 대통령이 한미군사훈련까지 대폭 축소하며 대화의 손길을 내민 직후 북한이 미사일로 응답하자 동맹 방어를 다시 강조한 겁니다.
# 대이란 전쟁에선 동맹국을 다시 압박하고 있습니다.
# 스콧 베선트 미 재무장관은 오는 24일 대이란 경제압박 계획을 공개하겠다며 세계 역사상 가장 강력하게 공조한 작전이 될 것이라고 예고했습니다.
# 그러면서 이제 동맹국이 결정을 내려야 할 시점이라면서 미국의 편인지, 아니면 미국에 맞설 것인지 양자택일 하라며 동참을 압박했습니다.
# 베선트 장관은 또 대이란 경제제재가 대규모 확전으로 이어질 가능성은 작다면서 이번 작전으로 유가가 내려갈 거라고 주장했습니다.
# [스콧 베선트 / 미국 재무부 장관 : 우리가 발표한 건 경제적 조치에 관한 것입니다. 그 경제적 조치로 인해 유가가 더 빨리 내려갈 것이라고 생각합니다.]
# 앞서 트럼프 대통령은 동맹국 뿐 아니라 이란과 거래하는 제3국도 막대한 경제적 대가를 치르게 될 거라고 경고했습니다.
# [도널드 트럼프 / 미국 대통령(현지시간 19일) : 우리가 제재할 수 있는 수단이 있습니다. 매우 강력한 제재 수단이 마련되어 있으니, 어떻게 될지 지켜보겠습니다]
# 트럼프 행정부의 동맹국에 대한 오락가락한 태도에 정치권의 비판도 이어지고 있습니다. 한국계 데이브 민 하원의원은 트럼프 대통령이 가장 가까운 동맹국을 소외시키고 평화를 위태롭게 하고 있다고 지적했습니다.
# 워싱턴에서 YTN 홍상희입니다.
# 촬영 : 강연오
# YTN 홍상희 (san@ytn.co.kr)
# ※ '당신의 제보가 뉴스가 됩니다'
# [카카오톡] YTN 검색해 채널 추가
# [전화] 02-398-8585
# [메일] social@ytn.co.kr
# [저작권자(c) YTN 무단전재, 재배포 및 AI 데이터 활용 금지]

# %%
def extract_news_page(url):
    html = request.urlopen(url).read()
    soup = BeautifulSoup(html, 'html.parser')
    title = soup.select_one('h3.tit_view').text
    author = soup.select_one('span.txt_info').text
    date = soup.select_one('span.num_date').text
    news_
    
    '\n'.join([art.get_text().strip() for art in soup.select('[dmcf-ptype="general"]')])

    return title, author, date, article

# %% [markdown]
# ### 4. 하이퍼링크된 모든 기사의 제목과 본문 추출하기

# %%
def print_news_page(url):
    title, author, date, article = extract_news_page(url)
    print('='*30)
    print(f'기사제목:{title}\n기자:{author}\n작성일:{date}\n\n뉴스내용:{article}')

# %%
for url in link_list:
    print_news_page(url)
    break;
# Out:
# ==============================
# 기사제목:북한 미사일에 미 "동맹 방어 전념"...대이란 작전엔 동맹 참여 압박
# 기자:홍상희
# 작성일:2026. 8. 21. 09:37
#
# 뉴스내용:[앵커]
# 북한의 탄도미사일 도발에 미국은 위협이 안 된다고 평가하면서 동맹국 방어에 전념하고 있다고 강조했습니다.
# 대이란 경제 고립 작전에 대해서는 미국의 편인지 아닌지 선택하라며 동맹국에 동참을 압박했습니다.
# 워싱턴 홍상희 특파원입니다.
# [기자]
# 북한의 단거리 탄도미사일 발사 하루 만에 미 태평양사령부가 성명을 발표했습니다.
# 미 태평양사령부는 북한의 미사일 발사가 미국이나 동맹국들에게 즉각적인 위협이 되지 않는다고 밝혔습니다.
# 또 미국 본토와 동맹국 방어에 전념하고 있다고 덧붙였습니다.
# 도널드 트럼프 대통령이 한미군사훈련까지 대폭 축소하며 대화의 손길을 내민 직후 북한이 미사일로 응답하자 동맹 방어를 다시 강조한 겁니다.
# 대이란 전쟁에선 동맹국을 다시 압박하고 있습니다.
# 스콧 베선트 미 재무장관은 오는 24일 대이란 경제압박 계획을 공개하겠다며 세계 역사상 가장 강력하게 공조한 작전이 될 것이라고 예고했습니다.
# 그러면서 이제 동맹국이 결정을 내려야 할 시점이라면서 미국의 편인지, 아니면 미국에 맞설 것인지 양자택일 하라며 동참을 압박했습니다.
# 베선트 장관은 또 대이란 경제제재가 대규모 확전으로 이어질 가능성은 작다면서 이번 작전으로 유가가 내려갈 거라고 주장했습니다.
# [스콧 베선트 / 미국 재무부 장관 : 우리가 발표한 건 경제적 조치에 관한 것입니다. 그 경제적 조치로 인해 유가가 더 빨리 내려갈 것이라고 생각합니다.]
# 앞서 트럼프 대통령은 동맹국 뿐 아니라 이란과 거래하는 제3국도 막대한 경제적 대가를 치르게 될 거라고 경고했습니다.
# [도널드 트럼프 / 미국 대통령(현지시간 19일) : 우리가 제재할 수 있는 수단이 있습니다. 매우 강력한 제재 수단이 마련되어 있으니, 어떻게 될지 지켜보겠습니다]
# 트럼프 행정부의 동맹국에 대한 오락가락한 태도에 정치권의 비판도 이어지고 있습니다. 한국계 데이브 민 하원의원은 트럼프 대통령이 가장 가까운 동맹국을 소외시키고 평화를 위태롭게 하고 있다고 지적했습니다.
# 워싱턴에서 YTN 홍상희입니다.
# 촬영 : 강연오
# YTN 홍상희 (san@ytn.co.kr)
# ※ '당신의 제보가 뉴스가 됩니다'
# [카카오톡] YTN 검색해 채널 추가
# [전화] 02-398-8585
# [메일] social@ytn.co.kr
# [저작권자(c) YTN 무단전재, 재배포 및 AI 데이터 활용 금지]

# %% [markdown]
# ### 추출한 기사내용과 정보를 데이터프레임과 csv파일로 저장

# %%
def save_news_data(url_list):
    title_list, author_list, date_list, article_list = [], [], [], []
    for url in url_list:
        title, author, date, article = extract_news_page(url)
        title_list.append(title)
        author_list.append(author)
        date_list.append(date)
        article_list.append(article)
    return {'제목':title_list, '작성자':author_list,
            '작성일':date_list, '뉴스내용':article_list}

# %%
news_dict = save_news_data(link_list).copy()
news_df = pd.DataFrame(data=news_dict)
news_df.to_csv('crawl_data/daum_news_pages.csv', index=False)
news_df
# Out:
#                                                    제목                 작성자  \
# 0             북한 미사일에 미 "동맹 방어 전념"...대이란 작전엔 동맹 참여 압박                 홍상희
# 1               8월 중순 수출 56%↑…반도체 비중 47.2%, 역대 최고(종합)                 안채원
# 2                  베선트 '바이백 총력전'…40조달러 부채에 금리 재상승(종합)          뉴욕(미국)=황윤주
# 3                AI데이터센터 주민 불만, 美 중간선거 쟁점으로[글로벌AI브리핑]                 이구순
# 4            사상 최고치 찍었는데 전문가들 "더 오른다"…AI 시대 주목받는 원자재는                 송화정
# 5   "8·13 대책, 그래서 대출 나온다고?"...2030 '영끌' 전략은[집 나와라 ...                 전민경
# 6              與복기왕 “지역주택조합·리모델링 규제 함께 푼다…도심 주택공급 속도”                 양대근
# 7                      트럼프 '러브콜'에도 미사일 10여 발⋯북한은 또 침묵                 최민성
# 8         SK하이닉스, 40조+10조 자사주 추가 매입…노사 합의로 ‘주주가치 선순환’              구경우 기자
# 9            마라에 빠져 직장 박차고 떠난 중국... 부산 '성지' 된 라라관의 비밀  2026. 8. 21. 04:31
# 10              “5남매 엄마 겁났지만… 힘든 건 곱하기 2, 행복은 곱하기 10”           대구/안준용 기자
# 11  [인터뷰] 이현태 금정산국립공원사무소장 “금정산, 이용하는 산에서 함께 지켜가는 산으로”                 김동우
# 12              별 볼 일 없는 하루라고요? ‘벌 볼 일’은 많습니다! [사람IN]              김연희 기자
# 13                  “보수는 무식한데 진보는…” 1020 남성들이 극우 된 까닭            김태호, 조은재
# 14                                 [그래픽] 최근 북한 미사일 발사                 전진우
# 15                                  20년 [굽시니스트 시사 만화]               굽시니스트
#
#                    작성일                                               뉴스내용
# 0   2026. 8. 21. 09:37  [앵커]\n북한의 탄도미사일 도발에 미국은 위협이 안 된다고 평가하면서 동맹국 방어...
# 1   2026. 8. 21. 09:31  [앵커]\n북한의 탄도미사일 도발에 미국은 위협이 안 된다고 평가하면서 동맹국 방어...
# 2   2026. 8. 21. 09:10  [앵커]\n북한의 탄도미사일 도발에 미국은 위협이 안 된다고 평가하면서 동맹국 방어...
# 3   2026. 8. 21. 09:09  [앵커]\n북한의 탄도미사일 도발에 미국은 위협이 안 된다고 평가하면서 동맹국 방어...
# 4   2026. 8. 21. 08:19  [앵커]\n북한의 탄도미사일 도발에 미국은 위협이 안 된다고 평가하면서 동맹국 방어...
# 5   2026. 8. 21. 08:02  [앵커]\n북한의 탄도미사일 도발에 미국은 위협이 안 된다고 평가하면서 동맹국 방어...
# 6   2026. 8. 21. 07:53  [앵커]\n북한의 탄도미사일 도발에 미국은 위협이 안 된다고 평가하면서 동맹국 방어...
# 7   2026. 8. 21. 07:18  [앵커]\n북한의 탄도미사일 도발에 미국은 위협이 안 된다고 평가하면서 동맹국 방어...
# 8   2026. 8. 21. 07:01  [앵커]\n북한의 탄도미사일 도발에 미국은 위협이 안 된다고 평가하면서 동맹국 방어...
# 9   2026. 8. 21. 04:31  [앵커]\n북한의 탄도미사일 도발에 미국은 위협이 안 된다고 평가하면서 동맹국 방어...
# 10  2026. 8. 21. 00:39  [앵커]\n북한의 탄도미사일 도발에 미국은 위협이 안 된다고 평가하면서 동맹국 방어...
# 11  2026. 8. 20. 17:53  [앵커]\n북한의 탄도미사일 도발에 미국은 위협이 안 된다고 평가하면서 동맹국 방어...
# 12  2026. 8. 20. 07:54  [앵커]\n북한의 탄도미사일 도발에 미국은 위협이 안 된다고 평가하면서 동맹국 방어...
# 13  2026. 8. 20. 05:02  [앵커]\n북한의 탄도미사일 도발에 미국은 위협이 안 된다고 평가하면서 동맹국 방어...
# 14  2026. 8. 21. 09:34  [앵커]\n북한의 탄도미사일 도발에 미국은 위협이 안 된다고 평가하면서 동맹국 방어...
# 15  2026. 8. 21. 09:30  [앵커]\n북한의 탄도미사일 도발에 미국은 위협이 안 된다고 평가하면서 동맹국 방어...

# %% [markdown]
# -------
