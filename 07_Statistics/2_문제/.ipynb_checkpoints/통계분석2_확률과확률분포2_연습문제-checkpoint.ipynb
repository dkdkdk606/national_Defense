# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import scipy
print(f'numpy: {np.__version__}, pandas: {pd.__version__}, seaborn: {sns.__version__}, scipy: {scipy.__version__}')
# %precision 3
# Out:
# numpy: 2.5.3, pandas: 3.0.5, seaborn: 0.13.2, scipy: 1.18.0
# '%.3f'

# %%
plt.rcParams['font.family'] = 'Malgun Gothic'
plt.rcParams['axes.unicode_minus']=False

# %% [markdown]
# 5. 성공할 확률이 0.5이고 10회 시행할 경우, 다음을 계산하는 프로그램을 작성하고 결과를 나타내시오.
#    ① 성공한 횟수 X에 대해 확률을 계산하여 표로 나타내고 막대그래프로 나타내시오.
#    ② X에 대한 기댓값과 분산을 계산하시오.
#    ③ 누적확률 P(X≤5)을 계산하시오.

# %%
from scipy import stats
def show_table_bar(target_X):
    n, p = 10, 0.5
    rv = stats.binom(n, p)
    
    x= range(11)
    prob = rv.pmf(x)
    x_df=pd.DataFrame(x, prob, columns=['성공횟수','확률'])
    print(x_df)
        
    plt.bar(x, prob, color='blue')

    plt.bar(target_x, rv.pmf(target_x), color='red')
    
show_table_bar(6)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[11], line 15
#      11     plt.bar(x, prob, color='blue')
#      12
#      13     plt.bar(target_x, rv.pmf(target_x), color='red')
#      14
# ---> 15 show_table_bar(6)
#
# Cell In[11], line 8, in show_table_bar(target_X)
#       4     rv = stats.binom(n, p)
#       5
#       6     x= range(11)
#       7     prob = rv.pmf(x)
# ----> 8     x_df=pd.DataFrame(x, prob, columns=['성공횟수','확률'])
#       9     print(x_df)
#      10
#      11     plt.bar(x, prob, color='blue')
#
# File ~\miniconda3\envs\myenv\Lib\site-packages\pandas\core\frame.py:852, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     845         mgr = arrays_to_mgr(
#     846             arrays,
#     847             columns,
#     848             index,
#     849             dtype=dtype,
#     850         )
#     851     else:
# ...

# %% [markdown]
# 6. 성공할 확률이 0.3이고 5회 시행할 경우, 다음을 계산하는 프로그램을 작성하고 결과를 나타내시오.
#    ① 성공한 횟수 X에 대해 확률을 계산하여 표로 나타내고 막대그래프로 나타내시오.
#    ② X에 대한 기댓값과 분산을 계산하시오.
#    ③ 누적확률 P(X≤3)을 계산하시오.

# %% [markdown]
# 7. 동전을 100번 던졌을 경우 앞면이 나타난 횟수를 X라 할 때, $P(X \le k) = 0.9$를 만족하는 확률변수 k를 계산하시오.

# %% [markdown]
# 8. 프로그래밍 과목의 평균 점수는 75점이고, 표준편차가 10인 정규분포를 따른다고 한다. 점수가 상위 5% 안에 들어야 A학점을 준다고 하는데 A학점을 받으려면 몇 점 이상을 받아야 하는가?

# %% [markdown]
# 9. t분포에 대해서 P(-1≤X≤1)의 확률을 계산하되, 자유도가 10, 30, 50, 100인 경우의 확률을 각각 계산하고, 표준정규분포에 대해 P(-1≤Z≤1)의 확률과 비교하시오.

# %% [markdown]
# 10. 평균이 70이고 표준편차가 15인 정규분포를 따르는 난수 1,000개를 발생하여 이들의 확률분포를 히스토그램으로 나타내는 프로그램을 작성하시오.
