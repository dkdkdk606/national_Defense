# %% [markdown]
# ## t-검정 연습문제

# %% [markdown]
# ### 문제1. 초등학생 신체데이터
#
# 2018년 초등학생 키와 몸무게 자료이다. 초등학교 학년별로 남학생의 평균키와 여학생 평균키가 차이가 있는지 유의수준 5%에서 가설검정을 수행하시오.

# %%
pd.read_excel('data/학생건강검사_초등학생2018.xlsx')

# %%
# 데이터 전처리 : 확인

# %%
# 시각화

# %%
# 정규성 검정

# %%
# ttest 수행

# %% [markdown]
# 결론

# %% [markdown]
# ### 문제2.
#
# 초등학교 1학년 남자와 여자의 혈압에 차이가 있는지 유의수준 5%에서 가설검정을 수행하시오.(모분산을 모름)

# %%
male = [114, 96, 80, 102, 94, 94, 98, 92, 94, 100, 108, 110, 90, 90, 82, 106]
female = [108, 98, 88, 86, 100, 98, 104, 102, 94]

# %%
# 1. EDA

# %%
# 2. 정규성 검정

# %%
# 3. 등분산성 검정

# %%
# 4. 독립표본 ttest 수행

# %% [markdown]
# 결론:

# %% [markdown]
# ### 문제3.
# 50명이 수강한 파이썬 프로그래밍의 중간시험 시험성적이 기대보다 낮았다고 평가한 A교수는 중간시험 이후에 방과후 보충수업을 실시하였다. 기말시험 성적이 중간시험보다 나아졌는지에 대해 유의수준 5%하에서 검정하시오. (파이썬프로그래밍성적.xlsx)

# %% [markdown]
# ### 문제4.
# 전화기용 보조배터리를 생산하는 A전기는 한국과 중국 두 곳에 생산공장을 운영하고 있다. 최근 중국에 전력공급이 원활하지 않아 생산된 제품의 질이 낮아졌을것으로 생각되어 두 곳에서 생산한 제품 표본에 대해 충전 후 지속시간을 비교하고자 한다. 한국공장에서는 85개를 중국공장에서는 100개의 제품에 대해 조사하였고 두 공장 제품의 지속시간에 차이가 있는지 유의수준 5%하에서 가설을 세우고 검정하시오. (배터리 지속시간.xlsx)

# %% [markdown]
# ### 문제5.
# 대전과 광주 두 곳에 콜센터를 운영하고 있는 A커뮤니케이션은 최근 광주공장의 상담원들이 대전보다 낮은 급여를 받고있다는 민원을 다수 접수하였다. 이에 급여담당자는 지역에 대한 급여차별은 없으며 단지 근무시간에 따라 차등지급을 하고 있다고 발표하였고, 노동조합은 두 지역 상담원 100명을 임의로 선택하여 주당 근로시간을 조사하였다. 두 지역 상담원의 주당 근로시간에 차이가있는지 유의수준 5%하에서 가설을 세우고 검정하시오.
# (주당 근로시간.xlsx)

# %% [markdown]
# ### 문제6.
# K푸드는 사내 자전거 동호회의 신입회원 25명을 대상으로 동호회 가입 전과 동호회 가입 한달 후 체중을 비교하였다. 가입 후의 혈압이 가입 전보다 낮아진 것인지 대해 유의수준 5%하에서 가설을 세우고 검정하시오. (체중비교.xlsx)

# %% [markdown]
# ### 문제7.
# S전자는 최근 사내에 설치한 휴게실의 만족도(100점 만점)를 성별로 조사하였다. 성별에 따라 만족도 점수에 차이가 있는지에 대해 유의수준 1%하에서 가설을 세우고 검정하시오. (휴게실 만족도.xlsx)

# %% [markdown]
# ---
